# %% [markdown]
# <a href="https://colab.research.google.com/github/Haripriya-SV/Unemployment-analysis/blob/main/Sales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mlp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe(include='all')
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# Exploratory data analysis

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('------------------------------')
# Out:
# 1      1
# 138    1
# 128    1
# 129    1
# 130    1
#       ..
# 70     1
# 71     1
# 72     1
# 73     1
# 200    1
# Name: Unnamed: 0, Length: 200, dtype: int64
# ------------------------------
# 199.8    2
# 109.8    2
# 17.2     2
# 177.0    2
# 222.4    2
#         ..
# 139.3    1
# 216.8    1
# 199.1    1
# 26.8     1
# 232.1    1
# Name: TV, Length: 190, dtype: int64
# ------------------------------
# 4.1     3
# 5.7     3
# 13.9    2
# 14.3    2
# 36.9    2
#        ..
# 42.8    1
# 14.5    1
# 30.6    1
# 33.0    1
# 8.6     1
# Name: Radio, Length: 167, dtype: int64
# ------------------------------
# 9.3     3
# 25.6    3
# 8.7     3
# 34.6    2
# 8.5     2
#        ..
# 27.2    1
# 31.7    1
# 19.3    1
# 31.3    1
# 66.2    1
# Name: Newspaper, Length: 172, dtype: int64
# ------------------------------
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
details=['TV','Radio','Newspaper','sales']

# %%
for column in details:
    print(df[column].value_counts())
    plt.figure(figsize=(10,7))
    sns.countplot(x=df[column])
    plt.xticks(rotation=45)
    plt.show()
# Out:
# 199.8    2
# 109.8    2
# 17.2     2
# 177.0    2
# 222.4    2
#         ..
# 139.3    1
# 216.8    1
# 199.1    1
# 26.8     1
# 232.1    1
# Name: TV, Length: 190, dtype: int64
# 4.1     3
# 5.7     3
# 13.9    2
# 14.3    2
# 36.9    2
#        ..
# 42.8    1
# 14.5    1
# 30.6    1
# 33.0    1
# 8.6     1
# Name: Radio, Length: 167, dtype: int64
# 9.3     3
# 25.6    3
# 8.7     3
# 34.6    2
# 8.5     2
#        ..
# 27.2    1
# 31.7    1
# 19.3    1
# 31.3    1
# 66.2    1
# Name: Newspaper, Length: 172, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ...

# %%
df.hist(figsize=(20,10), grid=False, layout=(3, 4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09ccd915b0>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
for i in df.columns:
    plt.figure(figsize=[10,6])
    sns.kdeplot(x=i,data=df)

# %%
plt.plot(df,color='red',label='predicted')
plt.plot(details[0],color='purple',label="actual")
plt.xlabel("Date")
plt.ylabel("Sales")
leg = plt.legend()
plt.show()

# %%
plt.plot(df,color='yellow',label='predicted')
plt.plot(details[1],color='purple',label="actual")
plt.xlabel("Date")
plt.ylabel("Sales")
leg = plt.legend()
plt.show()

# %%
plt.plot(df,color='green',label='predicted')
plt.plot(details[2],color='purple',label="actual")
plt.xlabel("Date")
plt.ylabel("Sales")
leg = plt.legend()
plt.show()

# %%
plt.plot(df,color='blue',label='predicted')
plt.plot(details[3],color='purple',label="actual")
plt.xlabel("Date")
plt.ylabel("Sales")
leg = plt.legend()
plt.show()
